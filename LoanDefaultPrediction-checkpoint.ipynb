# %% [markdown]
# ![COUR_IPO.png](attachment:COUR_IPO.png)

# %% [markdown]
# # Welcome to the Data Science Coding Challange!
#
# Test your skills in a real-world coding challenge. Coding Challenges provide CS & DS Coding Competitions with Prizes and achievement badges!
#
# CS & DS learners want to be challenged as a way to evaluate if they’re job ready. So, why not create fun challenges and give winners something truly valuable such as complimentary access to select Data Science courses, or the ability to receive an achievement badge on their Coursera Skills Profile - highlighting their performance to recruiters.

# %% [markdown]
# ## Introduction
#
# In this challenge, you'll get the opportunity to tackle one of the most industry-relevant machine learning problems with a unique dataset that will put your modeling skills to the test. Financial loan services are leveraged by companies across many industries, from big banks to financial institutions to government loans. One of the primary objectives of companies with financial loan services is to decrease payment defaults and ensure that individuals are paying back their loans as expected. In order to do this efficiently and systematically, many companies employ machine learning to predict which individuals are at the highest risk of defaulting on their loans, so that proper interventions can be effectively deployed to the right audience.
#
# In this challenge, we will be tackling the loan default prediction problem on a very unique and interesting group of individuals who have taken financial loans.
#
# Imagine that you are a new data scientist at a major financial institution and you are tasked with building a model that can predict which individuals will default on their loan payments. We have provided a dataset that is a sample of individuals who received loans in 2021.
#
# This financial institution has a vested interest in understanding the likelihood of each individual to default on their loan payments so that resources can be allocated appropriately to support these borrowers. In this challenge, you will use your machine learning toolkit to do just that!

# %% [markdown]
# ## Understanding the Datasets

# %% [markdown]
# ### Train vs. Test
# In this competition, you’ll gain access to two datasets that are samples of past borrowers of a financial institution that contain information about the individual and the specific loan. One dataset is titled `train.csv` and the other is titled `test.csv`.
#
# `train.csv` contains 70% of the overall sample (255,347 borrowers to be exact) and importantly, will reveal whether or not the borrower has defaulted on their loan payments (the “ground truth”).
#
# The `test.csv` dataset contains the exact same information about the remaining segment of the overall sample (109,435 borrowers to be exact), but does not disclose the “ground truth” for each borrower. It’s your job to predict this outcome!
#
# Using the patterns you find in the `train.csv` data, predict whether the borrowers in `test.csv` will default on their loan payments, or not.

# %% [markdown]
# ### Dataset descriptions
# Both `train.csv` and `test.csv` contain one row for each unique Loan. For each Loan, a single observation (`LoanID`) is included during which the loan was active.
#
# In addition to this identifier column, the `train.csv` dataset also contains the target label for the task, a binary column `Default` which indicates if a borrower has defaulted on payments.
#
# Besides that column, both datasets have an identical set of features that can be used to train your model to make predictions. Below you can see descriptions of each feature. Familiarize yourself with them so that you can harness them most effectively for this machine learning task!

# %%
import pandas as pd
data_descriptions = pd.read_csv('data_descriptions.csv')
pd.set_option('display.max_colwidth', None)
data_descriptions
# Out:
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Would remove:
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas-2.2.2.dist-info/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/byteswap.cpython-311-darwin.so
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/byteswap.pyi
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/pandas_datetime.cpython-311-darwin.so
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/pandas_parser.cpython-311-darwin.so
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/sas.cpython-311-darwin.so
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_libs/sas.pyi
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/_version_meson.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/api/typing/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/compat/_constants.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/compat/compressors.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/_numba/extensions.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/array_algos/datetimelike_accumulations.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/array_algos/masked_accumulations.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/_arrow_string_mixins.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/_utils.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/accessors.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/core/methods/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/io/_util.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_calamine.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/pyproject.toml
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/apply/test_numba.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/categorical/test_map.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/datetimes/test_cumulative.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/floating/test_contains.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/integer/test_reduction.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/interval/test_formats.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/interval/test_interval_pyarrow.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/interval/test_overlaps.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/arrays/timedeltas/test_cumulative.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/index/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_array.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_astype.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_chained_assignment_deprecation.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_clip.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_constructors.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_core_functionalities.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_functions.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_interp_fillna.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_replace.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/copy_view/test_util.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/extension/base/accumulate.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/extension/test_masked.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/methods/test_info.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/methods/test_isetitem.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/methods/test_iterrows.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/methods/test_map.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/methods/test_size.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/test_arrow_interface.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/frame/test_repr.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/methods/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_all_methods.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_api.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_cumulative.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_numeric_only.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_raises.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/groupby/test_reductions.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/categorical/test_setops.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_asof.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_delete.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_map.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_normalize.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_resolution.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_round.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_to_julian_date.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_to_pydatetime.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_tz_convert.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_tz_localize.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/methods/test_unique.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/test_arithmetic.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/datetimes/test_iter.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/test_datetimelike.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/test_old_base.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexes/timedeltas/test_arithmetic.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/indexing/conftest.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/formats/test_ipython_compat.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/parser/test_concatenate_chunks.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/parser/test_upcast.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/sas/test_byteswap.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/test_gbq.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/test_http_headers.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/io/xml/conftest.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/libs/test_libalgos.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/interval/test_constructors.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/interval/test_contains.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/interval/test_formats.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/interval/test_overlaps.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/period/test_arithmetic.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/timedelta/methods/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/scalar/timestamp/methods/*
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/accessors/test_list_accessor.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/accessors/test_struct_accessor.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_add_prefix_suffix.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_case_when.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_info.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_map.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_size.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_to_numpy.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/methods/test_tolist.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/series/test_formats.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/tseries/offsets/test_common.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/tslibs/test_npy_units.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/tslibs/test_period.py
#     /Users/Sour/anaconda3/lib/python3.11/site-packages/pandas/tests/tslibs/test_strptime.py
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
#        Column_name Column_type Data_type  \
# 0           LoanID  Identifier    string
# 1              Age     Feature   integer
# 2           Income     Feature   integer
# 3       LoanAmount     Feature   integer
# 4      CreditScore     Feature   integer
# 5   MonthsEmployed     Feature   integer
# 6   NumCreditLines     Feature   integer
# 7     InterestRate     Feature     float
# 8         LoanTerm     Feature   integer
# 9         DTIRatio     Feature     float
# 10       Education     Feature    string
# 11  EmploymentType     Feature    string
# 12   MaritalStatus     Feature    string
# 13     HasMortgage     Feature    string
# 14   HasDependents     Feature    string
# 15     LoanPurpose     Feature    string
# 16     HasCoSigner     Feature    string
# 17         Default      Target   integer
#
#                                                                                           Description
# 0                                                                  A unique identifier for each loan.
# 1                                                                            The age of the borrower.
# 2                                                                  The annual income of the borrower.
# 3                                                                 The amount of money being borrowed.
# 4                                The credit score of the borrower, indicating their creditworthiness.
# 5                                                The number of months the borrower has been employed.
# 6                                                   The number of credit lines the borrower has open.
# 7                                                                     The interest rate for the loan.
# 8                                                              The term length of the loan in months.
# 9                  The Debt-to-Income ratio, indicating the borrower's debt compared to their income.
# 10  The highest level of education attained by the borrower (PhD, Master's, Bachelor's, High School).
# 11   The type of employment status of the borrower (Full-time, Part-time, Self-employed, Unemployed).
# 12                                    The marital status of the borrower (Single, Married, Divorced).
# 13                                                   Whether the borrower has a mortgage (Yes or No).
# 14                                                   Whether the borrower has dependents (Yes or No).
# 15                                  The purpose of the loan (Home, Auto, Education, Business, Other).
# 16                                                      Whether the loan has a co-signer (Yes or No).
# 17                   The binary target variable indicating whether the loan defaulted (1) or not (0).

# %% [markdown]
# ## How to Submit your Predictions to Coursera
# Submission Format:
#
# In this notebook you should follow the steps below to explore the data, train a model using the data in `train.csv`, and then score your model using the data in `test.csv`. Your final submission should be a dataframe (call it `prediction_df` with two columns and exactly 109,435 rows (plus a header row). The first column should be `LoanID` so that we know which prediction belongs to which observation. The second column should be called `predicted_probability` and should be a numeric column representing the __likelihood that the borrower will default__.
#
# Your submission will show an error if you have extra columns (beyond `LoanID` and `predicted_probability`) or extra rows. The order of the rows does not matter.
#
# The naming convention of the dataframe and columns are critical for our autograding, so please make sure to use the exact naming conventions of `prediction_df` with column names `LoanID` and `predicted_probability`!
#
# To determine your final score, we will compare your `predicted_probability` predictions to the source of truth labels for the observations in `test.csv` and calculate the [ROC AUC](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html). We choose this metric because we not only want to be able to predict which loans will default, but also want a well-calibrated likelihood score that can be used to target interventions and support most accurately.

# %% [markdown]
# ## Import Python Modules
#
# First, import the primary modules that will be used in this project. Remember as this is an open-ended project please feel free to make use of any of your favorite libraries that you feel may be useful for this challenge. For example some of the following popular packages may be useful:
#
# - pandas
# - numpy
# - Scipy
# - Scikit-learn
# - keras
# - maplotlib
# - seaborn
# - etc, etc

# %%
# Import required packages
# !pip install scikit-learn
# Data packages
import pandas as pd
import numpy as np





from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# Visualization Packages
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/QtPy-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbformat-5.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numexpr-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/cookiecutter-1.7.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/colorcet-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sacremoses-0.0.43.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyviz_comms-2.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/zict-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_client-7.4.9.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_repo_cli-1.0.41-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/intake-0.6.8.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda-23.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/watchdog-2.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_CoreServices-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tifffile-2021.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/requests-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytest-7.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytoolconfig-1.2.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclassic-0.5.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/imagecodecs-2021.8.26.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/itemloaders-1.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_Cocoa-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyOpenSSL-23.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/cryptography-41.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/torch-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/imageio-2.31.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_build-3.26.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/zstandard-0.19.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipython-8.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jinja2_time-0.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab-3.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Scrapy-2.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/w3lib-1.21.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_black-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/xlwings-0.29.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_libmamba_solver-23.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/brotlipy-0.7.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_fileid-0.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashader-0.15.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyarrow-11.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_FSEvents-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder-5.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook_shim-0.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Flask-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ypy_websocket-0.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/transformers-4.29.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/s3fs-2023.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/h5py-3.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbconvert-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numpydoc-1.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/aiobotocore-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/distributed-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scipy-1.10.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/gensim-4.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_index-0.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Twisted-22.10.0.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: scikit-learn in /Users/Sour/anaconda3/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/Sour/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/8b/d2/78e3342f5db363ddf92de84007d43e47c8bb24363bd509e1b75a5102a25d/scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Downloading scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.2.0 in /Users/Sour/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Sour/anaconda3/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Downloading scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 24.5 MB/s eta 0:00:0000:0100:01
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/QtPy-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbformat-5.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numexpr-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/cookiecutter-1.7.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/colorcet-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sacremoses-0.0.43.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyviz_comms-2.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/zict-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_client-7.4.9.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_repo_cli-1.0.41-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/intake-0.6.8.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda-23.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/watchdog-2.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_CoreServices-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tifffile-2021.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/requests-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytest-7.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytoolconfig-1.2.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclassic-0.5.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/imagecodecs-2021.8.26.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/itemloaders-1.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_Cocoa-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyOpenSSL-23.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/cryptography-41.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/torch-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/imageio-2.31.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_build-3.26.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/zstandard-0.19.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipython-8.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jinja2_time-0.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab-3.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Scrapy-2.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/w3lib-1.21.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_black-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/xlwings-0.29.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_libmamba_solver-23.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/brotlipy-0.7.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_fileid-0.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashader-0.15.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyarrow-11.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_FSEvents-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder-5.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook_shim-0.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Flask-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ypy_websocket-0.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/transformers-4.29.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/s3fs-2023.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/h5py-3.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbconvert-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numpydoc-1.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/aiobotocore-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/distributed-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scipy-1.10.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/gensim-4.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_index-0.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Twisted-22.10.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: scipy
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/QtPy-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbformat-5.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numexpr-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/cookiecutter-1.7.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/colorcet-3.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sacremoses-0.0.43.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyviz_comms-2.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/zict-2.2.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_client-7.4.9.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda_repo_cli-1.0.41-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/intake-0.6.8.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/conda-23.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/watchdog-2.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyobjc_framework_CoreServices-9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tifffile-2021.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/requests-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytest-7.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pytoolconfig-1.2.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclassic-0.5.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/imagecodecs-2021.8.26.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/itemloaders-1.0.4.dist-info due to invalid metadata entry 'name'
# Successfully installed scipy-1.14.0
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/spyder_kernels-2.4.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipykernel-6.19.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/ipywidgets-8.0.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/plotly-5.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/scikit_image-0.20.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/anaconda_navigator-2.4.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/navigator_updater-0.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/numba-0.57.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Sphinx-5.0.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyQt5_sip-12.11.0-py3.11-macosx-11.1-arm64.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sip-6.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server-1.23.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/dask-2023.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/hvplot-0.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/qtconsole-5.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/sympy-1.11.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/PyWavelets-1.4.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/prompt_toolkit-3.0.36.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/Werkzeug-2.2.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pooch-1.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_server_ydoc-0.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/tables-3.8.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/statsmodels-0.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/nbclient-0.5.13.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/yarl-1.8.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/matplotlib-3.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/keyring-23.13.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/astropy-5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_jsonrpc-1.0.0-py3.10.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/holoviews-1.17.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/responses-0.13.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_dateutil-2.8.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/pyerfa-2.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/parsel-1.6.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datashape-0.5.4-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/rope-1.7.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/python_lsp_server-1.7.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/panel-1.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/jupyter_events-0.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/bokeh-3.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/Sour/anaconda3/lib/python3.11/site-packages/datasets-2.12.0.dist-info due to invalid metadata entry 'name'

# %%
# Import any other packages you may want to use

# %% [markdown]
# ## Load the Data
#
# Let's start by loading the dataset `train.csv` into a dataframe `train_df`, and `test.csv` into a dataframe `test_df` and display the shape of the dataframes.

# %%
train_df = pd.read_csv("train.csv")
print('train_df Shape:', train_df.shape)
train_df.head()
# Out:
# train_df Shape: (255347, 18)
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
# 3      Full-time       Married          No            No    Business
# 4     Unemployed      Divorced          No           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1
# 3          No        0
# 4          No        0

# %%
test_df = pd.read_csv("test.csv")
print('test_df Shape:', test_df.shape)
test_df.head()
# Out:
# test_df Shape: (109435, 17)
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  7RYZGMKJIR   32  131645       43797          802              23
# 1  JDL5RH07AM   61  134312       18402          369              87
# 2  STAL716Y79   55  115809      151774          563               3
# 3  SO0KKJ3IQB   58   94970       55789          337              24
# 4  T99CWTYDCP   63   71727      189798          451              52
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               2          6.10        24      0.13  High School
# 1               2         12.99        60      0.59  High School
# 2               3          5.51        48      0.82   Bachelor's
# 3               1         23.93        36      0.77   Bachelor's
# 4               3         22.05        48      0.44          PhD
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes            No       Other
# 1  Self-employed        Single          No            No    Business
# 2      Full-time        Single         Yes           Yes       Other
# 3     Unemployed      Divorced          No            No    Business
# 4     Unemployed        Single         Yes            No        Auto
#
#   HasCoSigner
# 0          No
# 1         Yes
# 2         Yes
# 3          No
# 4          No

# %% [markdown]
# ## Explore, Clean, Validate, and Visualize the Data (optional)
#
# Feel free to explore, clean, validate, and visualize the data however you see fit for this competition to help determine or optimize your predictive model. Please note - the final autograding will only be on the accuracy of the `prediction_df` predictions.

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# Assuming 'train_df' is already loaded and contains the training data
numerical_cols = train_df.select_dtypes(include=['float64', 'int64']).columns

# Calculate the number of rows and columns for the subplot grid
num_numerical_cols = len(numerical_cols)
ncols = 4  # You can adjust this to your preference
nrows = math.ceil(num_numerical_cols / ncols)

# Plot histograms for all numerical columns
train_df[numerical_cols].hist(bins=15, figsize=(15, nrows * 3), layout=(nrows, ncols))
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout()  # Adjust layout to make room for the title and axis labels
plt.show()

# %% [markdown]
# ## Make predictions (required)
#
# Remember you should create a dataframe named `prediction_df` with exactly 109,435 entries plus a header row attempting to predict the likelihood of borrowers to default on their loans in `test_df`. Your submission will throw an error if you have extra columns (beyond `LoanID` and `predicted_probaility`) or extra rows.
#
# The file should have exactly 2 columns:
# `LoanID` (sorted in any order)
# `predicted_probability` (contains your numeric predicted probabilities between 0 and 1, e.g. from `estimator.predict_proba(X, y)[:, 1]`)
#
# The naming convention of the dataframe and columns are critical for our autograding, so please make sure to use the exact naming conventions of `prediction_df` with column names `LoanID` and `predicted_probability`!

# %% [markdown]
# ### Example prediction submission:
#
# The code below is a very naive prediction method that simply predicts loan defaults using a Dummy Classifier. This is used as just an example showing the submission format required. Please change/alter/delete this code below and create your own improved prediction methods for generating `prediction_df`.

# %% [markdown]
# **PLEASE CHANGE CODE BELOW TO IMPLEMENT YOUR OWN PREDICTIONS**

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# Load the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# Preprocess the data
# Example: Handle missing values if necessary
# train_df.dropna(inplace=True)

# Convert categorical variables using LabelEncoder
label_encoders = {}
for column in train_df.select_dtypes(include=['object', 'category']).columns:
    if column != 'LoanID' and column != 'Default':
        le = LabelEncoder()
        train_df[column] = le.fit_transform(train_df[column].astype(str))
        test_df[column] = le.transform(test_df[column].astype(str))
        label_encoders[column] = le

# Initialize the RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit the model on the training data
rf_clf.fit(train_df.drop(['LoanID', 'Default'], axis=1), train_df['Default'])

# Make predictions on the test dataset
predicted_probability = rf_clf.predict_proba(test_df.drop(['LoanID'], axis=1))[:, 1]

# Create the prediction dataframe
prediction_df = pd.DataFrame({
    'LoanID': test_df['LoanID'],
    'predicted_probability': predicted_probability
})

# Export to CSV
prediction_df.to_csv("prediction_submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 26
#      23 rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
#      25 # Fit the model on the training data
# ---> 26 rf_clf.fit(train_df.drop(['LoanID', 'Default'], axis=1), train_df['Default'])
#      28 # Make predictions on the test dataset
#      29 predicted_probability = rf_clf.predict_proba(test_df.drop(['LoanID'], axis=1))[:, 1]
#
# File /Library/Python/3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Python/3.9/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File /Library/Python/3.9/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /Library/Python/3.9/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /Library/Python/3.9/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /Library/Python/3.9/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /Library/Python/3.9/site-packages/sklearn/ensemble/_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File /Library/Python/3.9/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# Assuming rf_clf is your trained RandomForestClassifier model

# Step 2: Predict probabilities on the preprocessed test_df
predicted_probability = rf_clf.predict_proba(test_df.drop(['LoanID'], axis=1))[:, 1]

# Step 3: Create the prediction_df DataFrame with LoanID and the predicted probabilities
prediction_df = pd.DataFrame({
    'LoanID': test_df['LoanID'],
    'predicted_probability': predicted_probability
})

# Step 4: Ensure the dataframe meets the submission requirements
assert prediction_df.shape[0] == 109435, "The dataframe should have exactly 109,435 rows."
assert list(prediction_df.columns) == ['LoanID', 'predicted_probability'], "The dataframe columns should be exactly ['LoanID', 'predicted_probability']."

# %%
import bottleneck as bn

# Check bottleneck version
required_version = '1.3.6'
installed_version = bn.__version__

if installed_version < required_version:
    raise ImportError(f"Your bottleneck version is {installed_version}. Please update to version {required_version} or newer.")

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import roc_auc_score
from scipy.stats import randint

# Load the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# Preprocess the data
label_encoders = {}
for column in train_df.select_dtypes(include=['object', 'category']).columns:
    if column != 'LoanID' and column != 'Default':
        le = LabelEncoder()
        train_df[column] = le.fit_transform(train_df[column].astype(str))
        test_df[column] = le.transform(test_df[column].astype(str))
        label_encoders[column] = le

# Separate features and target
X = train_df.drop(['LoanID', 'Default'], axis=1)
y = train_df['Default']

# Initialize the RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=42)

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': randint(100, 500),
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 5),
    'bootstrap': [True, False]
}

# Initialize RandomizedSearchCV with StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(estimator=rf_clf, param_distributions=param_dist,
                                   n_iter=100, cv=cv, scoring='roc_auc', n_jobs=-1, verbose=2, random_state=42)

# Fit the RandomizedSearchCV
random_search.fit(X, y)

# Best parameters
best_params = random_search.best_params_

# Best model
best_rf_clf = random_search.best_estimator_

# Evaluate model using cross-validation
cv_auc = cross_val_score(best_rf_clf, X, y, cv=cv, scoring='roc_auc')
print(f"Cross-Validated AUC: {cv_auc.mean()}")

# Fit the best model on the entire training data
best_rf_clf.fit(X, y)

# Make predictions on the test dataset
predicted_probability = best_rf_clf.predict_proba(test_df.drop(['LoanID'], axis=1))[:, 1]

# Create the prediction dataframe
prediction_df = pd.DataFrame({
    'LoanID': test_df['LoanID'],
    'predicted_probability': predicted_probability
})

# Export to CSV
prediction_df.to_csv("prediction_submission.csv", index=False)

# %% [markdown]
# **PLEASE CHANGE CODE ABOVE TO IMPLEMENT YOUR OWN PREDICTIONS**

# %% [markdown]
# ## Final Tests - **IMPORTANT** - the cells below must be run prior to submission
#
# Below are some tests to ensure your submission is in the correct format for autograding. The autograding process accepts a csv `prediction_submission.csv` which we will generate from our `prediction_df` below. Please run the tests below an ensure no assertion errors are thrown.

# %%
# FINAL TEST CELLS - please make sure all of your code is above these test cells

# Writing to csv for autograding purposes
prediction_df.to_csv("prediction_submission.csv", index=False)
submission = pd.read_csv("prediction_submission.csv")

assert isinstance(submission, pd.DataFrame), 'You should have a dataframe named prediction_df.'

# %%
# FINAL TEST CELLS - please make sure all of your code is above these test cells

assert submission.columns[0] == 'LoanID', 'The first column name should be CustomerID.'
assert submission.columns[1] == 'predicted_probability', 'The second column name should be predicted_probability.'

# %%
# FINAL TEST CELLS - please make sure all of your code is above these test cells

assert submission.shape[0] == 109435, 'The dataframe prediction_df should have 109435 rows.'

# %%
# FINAL TEST CELLS - please make sure all of your code is above these test cells

assert submission.shape[1] == 2, 'The dataframe prediction_df should have 2 columns.'

# %%
# FINAL TEST CELLS - please make sure all of your code is above these test cells

## This cell calculates the auc score and is hidden. Submit Assignment to see AUC score.

# %% [markdown]
# ## SUBMIT YOUR WORK!
#
# Once we are happy with our `prediction_df` and `prediction_submission.csv` we can now submit for autograding! Submit by using the blue **Submit Assignment** at the top of your notebook. Don't worry if your initial submission isn't perfect as you have multiple submission attempts and will obtain some feedback after each submission!
